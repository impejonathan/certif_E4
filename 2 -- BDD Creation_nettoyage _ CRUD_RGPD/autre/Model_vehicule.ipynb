# %%
import os
from dotenv import load_dotenv
import pyodbc
import pandas as pd

# Charger les variables d'environnement
load_dotenv()

# server = os.getenv('DB_SERVER')
# database = os.getenv('DB_DATABASE')
# username = os.getenv('DB_USERNAME')
# password = os.getenv('DB_PASSWORD')

# driver= '{ODBC Driver 17 for SQL Server}'

# cnxn = pyodbc.connect('DRIVER='+driver+';SERVER='+server+';PORT=1433;DATABASE='+database+';UID='+username+';PWD='+ password)
# cursor = cnxn.cursor()
# Out:
# True

# %% [markdown]
# Voici une liste des 100 voitures les plus vendues en France depuis les 15 dernières années. Veuillez noter que les chiffres sont basés sur les données disponibles et peuvent varier légèrement.
#
# 1. Renault Clio
# 2. Peugeot 208
# 3. Peugeot 308
# 4. Renault Mégane
# 5. Citroën C3
# 6. Dacia Sandero
# 7. Peugeot 207
# 8. Renault Scénic
# 9. Citroën C4
# 10. Peugeot 307
# 11. Volkswagen Polo
# 12. Renault Captur
# 13. Peugeot 206
# 14. Citroën C4 Picasso
# 15. Volkswagen Golf
# 16. Nissan Qashqai
# 17. Ford Fiesta
# 18. Opel Corsa
# 19. Renault Twingo
# 20. Citroën DS3
# 21. Fiat 500
# 22. Toyota Yaris
# 23. Dacia Duster
# 24. BMW Série 1
# 25. Audi A3
# 26. Mercedes-Benz Classe A
# 27. Peugeot 108
# 28. Citroën C1
# 29. Toyota Aygo
# 30. Volkswagen Tiguan
# 31. Renault Kangoo
# 32. Peugeot Partner
# 33. Citroën Berlingo
# 34. Ford Focus
# 35. Volkswagen Passat
# 36. BMW Série 3
# 37. Audi A4
# 38. Mercedes-Benz Classe C
# 39. Renault Zoé
# 40. Peugeot 508
# 41. Citroën C5
# 42. Volvo XC60
# 43. Land Rover Evoque
# 44. Skoda Octavia
# 45. Seat Ibiza
# 46. Hyundai i10
# 47. Kia Rio
# 48. Suzuki Swift
# 49. Honda Jazz
# 50. Mazda 2
# 51. Mitsubishi ASX
# 52. Subaru XV
# 53. Jeep Renegade
# 54. Alfa Romeo Giulietta
# 55. Lancia Ypsilon
# 56. Smart Fortwo
# 57. Mini Cooper
# 58. Chevrolet Aveo
# 59. Chrysler 300C
# 60. Cadillac Escalade
# 61. Tesla Model S
# 62. Porsche 911
# 63. Ferrari 488
# 64. Lamborghini Huracan
# 65. McLaren 570S
# 66. Aston Martin DB11
# 67. Bentley Continental GT
# 68. Rolls-Royce Phantom
# 69. Maserati Ghibli
# 70. Jaguar F-Type
# 71. Lexus NX
# 72. Infiniti Q30
# 73. DS Automobiles DS 3
# 74. DS Automobiles DS 4
# 75. DS Automobiles DS 5
# 76. Renault Espace
# 77. Peugeot 807
# 78. Citroën C8
# 79. Fiat Ulysse
# 80. Lancia Phedra
# 81. Mercedes-Benz Viano
# 82. Volkswagen Sharan
# 83. Seat Alhambra
# 84. Ford S-Max
# 85. Renault Koleos
# 86. Peugeot 4007
# 87. Citroën C-Crosser
# 88. Mitsubishi Outlander
# 89. Subaru Forester
# 90. Jeep Grand Cherokee
# 91. Land Rover Discovery
# 92. Toyota Land Cruiser
# 93. Nissan Patrol
# 94. Skoda Yeti
# 95. Seat Arona
# 96. Hyundai Kona
# 97. Kia Stonic
# 98. Suzuki Vitara
# 99. Honda HR-V
# 100. Mazda CX-3

# %%
import pandas as pd

# Créer une liste de dictionnaires pour les données
data = [
    {"Marque_Voiture": "Renault", "Modele": "Clio 3", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Renault", "Modele": "Clio 4", "Largeur": 195, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Renault", "Modele": "Clio 5", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "208", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "308", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Renault", "Modele": "Mégane 3", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Renault", "Modele": "Mégane 4", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Citroën", "Modele": "C3", "Largeur": 185, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Dacia", "Modele": "Sandero 1", "Largeur": 185, "Hauteur": 60, "Diametre": 15},
    {"Marque_Voiture": "Dacia", "Modele": "Sandero 2", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Dacia", "Modele": "Sandero 3", "Largeur": 205, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Peugeot", "Modele": "207", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Renault", "Modele": "Scénic 3", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Citroën", "Modele": "C4", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "307", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Volkswagen", "Modele": "Polo", "Largeur": 185, "Hauteur": 60, "Diametre": 15},
    {"Marque_Voiture": "Renault", "Modele": "Captur", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "206", "Largeur": 185, "Hauteur": 60, "Diametre": 14},
    {"Marque_Voiture": "Citroën", "Modele": "C4 Picasso", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Volkswagen", "Modele": "Golf", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Nissan", "Modele": "Qashqai", "Largeur": 215, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Ford", "Modele": "Fiesta", "Largeur": 195, "Hauteur": 50, "Diametre": 15},
    {"Marque_Voiture": "Opel", "Modele": "Corsa", "Largeur": 185, "Hauteur": 60, "Diametre": 15},
    {"Marque_Voiture": "Renault", "Modele": "Twingo", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Citroën", "Modele": "DS3", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Fiat", "Modele": "500", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Toyota", "Modele": "Yaris", "Largeur": 175, "Hauteur": 60, "Diametre": 15},
    {"Marque_Voiture": "Dacia", "Modele": "Duster", "Largeur": 215, "Hauteur": 65, "Diametre": 16},
    {"Marque_Voiture": "BMW", "Modele": "Série 1", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Audi", "Modele": "A3", "Largeur": 225, "Hauteur": 40, "Diametre": 18},
    {"Marque_Voiture": "Mercedes-Benz", "Modele": "Classe A", "Largeur": 205, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "108", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Citroën", "Modele": "C1", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Toyota", "Modele": "Aygo", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Volkswagen", "Modele": "Tiguan", "Largeur": 215, "Hauteur": 60, "Diametre": 17},
      {"Marque_Voiture": "Renault", "Modele": "Kangoo", "Largeur": 195, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Peugeot", "Modele": "Partner", "Largeur": 185, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Citroën", "Modele": "Berlingo", "Largeur": 195, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Ford", "Modele": "Focus", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Volkswagen", "Modele": "Passat", "Largeur": 225, "Hauteur": 50, "Diametre": 17},
    {"Marque_Voiture": "BMW", "Modele": "Série 3", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Audi", "Modele": "A4", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Mercedes-Benz", "Modele": "Classe C", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Renault", "Modele": "Zoé", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "Peugeot", "Modele": "508", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Citroën", "Modele": "C5", "Largeur": 225, "Hauteur": 50, "Diametre": 17},
    {"Marque_Voiture": "Volvo", "Modele": "XC60", "Largeur": 235, "Hauteur": 55, "Diametre": 18},
    {"Marque_Voiture": "Land Rover", "Modele": "Evoque", "Largeur": 235, "Hauteur": 55, "Diametre": 18},
    {"Marque_Voiture": "Skoda", "Modele": "Octavia", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Seat", "Modele": "Ibiza", "Largeur": 195, "Hauteur": 50, "Diametre": 15},
    {"Marque_Voiture": "Hyundai", "Modele": "i10", "Largeur": 165, "Hauteur": 65, "Diametre": 14},
    {"Marque_Voiture": "Kia", "Modele": "Rio", "Largeur": 195, "Hauteur": 50, "Diametre": 15},
    {"Marque_Voiture": "Suzuki", "Modele": "Swift", "Largeur": 185, "Hauteur": 55, "Diametre": 15},
    {"Marque_Voiture": "Honda", "Modele": "Jazz", "Largeur": 185, "Hauteur": 55, "Diametre": 15},
    {"Marque_Voiture": "Mazda", "Modele": "2", "Largeur": 185, "Hauteur": 55, "Diametre": 15},
    {"Marque_Voiture": "Mitsubishi", "Modele": "ASX", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Subaru", "Modele": "XV", "Largeur": 225, "Hauteur": 55, "Diametre": 17},
    {"Marque_Voiture": "Jeep", "Modele": "Renegade", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Alfa Romeo", "Modele": "Giulietta", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "Lancia", "Modele": "Ypsilon", "Largeur": 175, "Hauteur": 60, "Diametre": 15},
    {"Marque_Voiture": "Smart", "Modele": "Fortwo", "Largeur": 155, "Hauteur": 65, "Diametre": 15},
    {"Marque_Voiture": "Mini", "Modele": "Cooper", "Largeur": 195, "Hauteur": 50, "Diametre": 16},
    {"Marque_Voiture": "Chevrolet", "Modele": "Aveo", "Largeur": 185, "Hauteur": 55, "Diametre": 15},
    
    {"Marque_Voiture": "Tesla", "Modele": "Model S", "Largeur": 245, "Hauteur": 45, "Diametre": 19},
    {"Marque_Voiture": "Porsche", "Modele": "911", "Largeur": 245, "Hauteur": 35, "Diametre": 20},
    {"Marque_Voiture": "Ferrari", "Modele": "488", "Largeur": 245, "Hauteur": 35, "Diametre": 20},
    {"Marque_Voiture": "Lamborghini", "Modele": "Huracan", "Largeur": 245, "Hauteur": 30, "Diametre": 20},
    {"Marque_Voiture": "McLaren", "Modele": "570S", "Largeur": 225, "Hauteur": 35, "Diametre": 19},
    {"Marque_Voiture": "Aston Martin", "Modele": "DB11", "Largeur": 245, "Hauteur": 40, "Diametre": 20},
    {"Marque_Voiture": "Bentley", "Modele": "Continental GT", "Largeur": 275, "Hauteur": 40, "Diametre": 20},
    {"Marque_Voiture": "Rolls-Royce", "Modele": "Phantom", "Largeur": 255, "Hauteur": 45, "Diametre": 21},
    {"Marque_Voiture": "Maserati", "Modele": "Ghibli", "Largeur": 245, "Hauteur": 40, "Diametre": 19},
    {"Marque_Voiture": "Jaguar", "Modele": "F-Type", "Largeur": 255, "Hauteur": 35, "Diametre": 20},
    {"Marque_Voiture": "Lexus", "Modele": "NX", "Largeur": 225, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Infiniti", "Modele": "Q30", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "DS Automobiles", "Modele": "DS 3", "Largeur": 195, "Hauteur": 55, "Diametre": 16},
    {"Marque_Voiture": "DS Automobiles", "Modele": "DS 4", "Largeur": 225, "Hauteur": 45, "Diametre": 17},
    {"Marque_Voiture": "DS Automobiles", "Modele": "DS 5", "Largeur": 225, "Hauteur": 45, "Diametre": 18},
    {"Marque_Voiture": "Renault", "Modele": "Espace", "Largeur": 225, "Hauteur": 55, "Diametre": 17},
    {"Marque_Voiture": "Peugeot", "Modele": "807", "Largeur": 215, "Hauteur": 65, "Diametre": 16},
    {"Marque_Voiture": "Citroën", "Modele": "C8", "Largeur": 215, "Hauteur": 65, "Diametre": 16},
    {"Marque_Voiture": "Fiat", "Modele": "Ulysse", "Largeur": 215, "Hauteur": 65, "Diametre": 16},
    {"Marque_Voiture": "Lancia", "Modele": "Phedra", "Largeur": 215, "Hauteur": 65, "Diametre": 16},
    
    {"Marque_Voiture": "Mercedes-Benz", "Modele": "Viano", "Largeur": 225, "Hauteur": 65, "Diametre": 16},
    {"Marque_Voiture": "Volkswagen", "Modele": "Sharan", "Largeur": 235, "Hauteur": 55, "Diametre": 17},
    {"Marque_Voiture": "Seat", "Modele": "Alhambra", "Largeur": 235, "Hauteur": 55, "Diametre": 17},
    {"Marque_Voiture": "Ford", "Modele": "S-Max", "Largeur": 235, "Hauteur": 50, "Diametre": 17},
    {"Marque_Voiture": "Renault", "Modele": "Koleos", "Largeur": 225, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Peugeot", "Modele": "4007", "Largeur": 235, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Citroën", "Modele": "C-Crosser", "Largeur": 235, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Mitsubishi", "Modele": "Outlander", "Largeur": 225, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Subaru", "Modele": "Forester", "Largeur": 225, "Hauteur": 60, "Diametre": 17},
    {"Marque_Voiture": "Jeep", "Modele": "Grand Cherokee", "Largeur": 265, "Hauteur": 50, "Diametre": 18},
    {"Marque_Voiture": "Land Rover", "Modele": "Discovery", "Largeur": 255, "Hauteur": 60, "Diametre": 18},
    {"Marque_Voiture": "Toyota", "Modele": "Land Cruiser", "Largeur": 285, "Hauteur": 65, "Diametre": 17},
    {"Marque_Voiture": "Nissan", "Modele": "Patrol", "Largeur": 295, "Hauteur": 65, "Diametre": 18},
    {"Marque_Voiture": "Skoda", "Modele": "Yeti", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Seat", "Modele": "Arona", "Largeur": 215, "Hauteur": 50, "Diametre": 16},
    {"Marque_Voiture": "Hyundai", "Modele": "Kona", "Largeur": 215, "Hauteur": 50, "Diametre": 16},
    {"Marque_Voiture": "Kia", "Modele": "Stonic", "Largeur": 215, "Hauteur": 50, "Diametre": 16},
    {"Marque_Voiture": "Suzuki", "Modele": "Vitara", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Honda", "Modele": "HR-V", "Largeur": 215, "Hauteur": 60, "Diametre": 16},
    {"Marque_Voiture": "Mazda", "Modele": "CX-3", "Largeur": 215, "Hauteur": 50, "Diametre": 16},


]

# Créer le DataFrame à partir des données
df = pd.DataFrame(data)

# Afficher le DataFrame
print(df)
# Out:
#       Marque  Modele  Largeur  Hauteur  Diametre
# 0    Renault  Clio 3      195       55        16
# 1    Renault  Clio 4      195       65        15
# 2    Renault  Clio 5      205       55        16
# 3    Peugeot     208      195       55        16
# 4    Peugeot     308      225       45        17
# ..       ...     ...      ...      ...       ...
# 98   Hyundai    Kona      215       50        16
# 99       Kia  Stonic      215       50        16
# 100   Suzuki  Vitara      215       60        16
# 101    Honda    HR-V      215       60        16
# 102    Mazda    CX-3      215       50        16
#
# [103 rows x 5 columns]

# %%
# Enregistrer le DataFrame sous forme de fichier CSV
df.to_csv("tailles_de_pneus_par_voiture.csv", index=False)
